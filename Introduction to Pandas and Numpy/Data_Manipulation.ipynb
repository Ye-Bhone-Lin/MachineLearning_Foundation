# %%
import pandas

df = pandas.read_csv("/content/earthquake_1995-2023.csv")
df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
# ...

# %%
df.columns
# Out:
# Index(['title', 'magnitude', 'date_time', 'cdi', 'mmi', 'alert', 'tsunami',
#        'sig', 'net', 'nst', 'dmin', 'gap', 'magType', 'depth', 'latitude',
#        'longitude', 'location', 'continent', 'country'],
#       dtype='object')

# %%
final_df = df[['magnitude','cdi',"date_time","location"]]
final_df
# Out:
#      magnitude  cdi         date_time               location
# 0          6.5    7  16-08-2023 12:47          Sola, Vanuatu
# 1          6.5    8  19-07-2023 00:22  Intipucá, El Salvador
# 2          6.6    7  17-07-2023 03:05    Loncopué, Argentina
# 3          7.2    6  16-07-2023 06:48     Sand Point, Alaska
# 4          7.3    0  16-07-2023 06:48       Alaska Peninsula
# ..         ...  ...               ...                    ...
# 995        7.1    0  27-05-1995 13:03         Tungor, Russia
# 996        7.7    0  16-05-1995 20:12     Vao, New Caledonia
# 997        6.9    0  14-05-1995 11:33   Maubara, Timor Leste
# 998        6.6    0  13-05-1995 08:47          Aianí, Greece
# 999        7.1    0  05-05-1995 03:53  Cabatuan, Philippines
#
# [1000 rows x 4 columns]

# %%
final_df['location_prices'] = 1000
# Out:
# <ipython-input-15-1542cfdd6591>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['location_prices'] = 1000

# %%
final_df
# Out:
#      magnitude  cdi         date_time               location  location_prices
# 0          6.5    7  16-08-2023 12:47          Sola, Vanuatu             1000
# 1          6.5    8  19-07-2023 00:22  Intipucá, El Salvador             1000
# 2          6.6    7  17-07-2023 03:05    Loncopué, Argentina             1000
# 3          7.2    6  16-07-2023 06:48     Sand Point, Alaska             1000
# 4          7.3    0  16-07-2023 06:48       Alaska Peninsula             1000
# ..         ...  ...               ...                    ...              ...
# 995        7.1    0  27-05-1995 13:03         Tungor, Russia             1000
# 996        7.7    0  16-05-1995 20:12     Vao, New Caledonia             1000
# 997        6.9    0  14-05-1995 11:33   Maubara, Timor Leste             1000
# 998        6.6    0  13-05-1995 08:47          Aianí, Greece             1000
# 999        7.1    0  05-05-1995 03:53  Cabatuan, Philippines             1000
#
# [1000 rows x 5 columns]

# %%
final_df['magnitude'].min()
# Out:
# 6.5

# %%
final_df['magnitude'].mean()
# Out:
# np.float64(6.940150000000001)

# %%
final_df["testing"]  = final_df['magnitude'] + final_df['cdi']
final_df
# Out:
# <ipython-input-23-55b20bb825a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["testing"]  = final_df['magnitude'] + final_df['cdi']
#      magnitude  cdi         date_time               location  location_prices  \
# 0          6.5    7  16-08-2023 12:47          Sola, Vanuatu             1000
# 1          6.5    8  19-07-2023 00:22  Intipucá, El Salvador             1000
# 2          6.6    7  17-07-2023 03:05    Loncopué, Argentina             1000
# 3          7.2    6  16-07-2023 06:48     Sand Point, Alaska             1000
# 4          7.3    0  16-07-2023 06:48       Alaska Peninsula             1000
# ..         ...  ...               ...                    ...              ...
# ...

# %%
final_df["testing1"]  = final_df['magnitude'] / final_df['cdi']
# Out:
# <ipython-input-24-7718ad1eec2d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["testing1"]  = final_df['magnitude'] / final_df['cdi']

# %%
final_df
# Out:
#      magnitude  cdi         date_time               location  location_prices  \
# 0          6.5    7  16-08-2023 12:47          Sola, Vanuatu             1000
# 1          6.5    8  19-07-2023 00:22  Intipucá, El Salvador             1000
# 2          6.6    7  17-07-2023 03:05    Loncopué, Argentina             1000
# 3          7.2    6  16-07-2023 06:48     Sand Point, Alaska             1000
# 4          7.3    0  16-07-2023 06:48       Alaska Peninsula             1000
# ..         ...  ...               ...                    ...              ...
# 995        7.1    0  27-05-1995 13:03         Tungor, Russia             1000
# 996        7.7    0  16-05-1995 20:12     Vao, New Caledonia             1000
# 997        6.9    0  14-05-1995 11:33   Maubara, Timor Leste             1000
# 998        6.6    0  13-05-1995 08:47          Aianí, Greece             1000
# 999        7.1    0  05-05-1995 03:53  Cabatuan, Philippines             1000
#
#      testing  testing1
# ...

# %%
final_df['location'].value_counts()
# Out:
# location
# Kokopo, Papua New Guinea     29
# Sola, Vanuatu                19
# Kirakira, Solomon Islands    18
# Panguna, Papua New Guinea    17
# Kimbe, Papua New Guinea      15
#                              ..
# Thang, India                  1
# Changuillo, Peru              1
# Nishinoomote, Japan           1
# Paphos, Cyprus                1
# Palapag, Philippines          1
# Name: count, Length: 502, dtype: int64

# %%
final_df.sort_values('cdi')
# Out:
#      magnitude  cdi         date_time                   location  \
# 752        6.8    0  20-06-2003 13:30              Ovalle, Chile
# 708        7.1    0  26-11-2004 02:25          Nabire, Indonesia
# 712        6.7    0  11-11-2004 17:34  Kirakira, Solomon Islands
# 714        6.6    0  23-10-2004 08:56               Ojiya, Japan
# 716        7.0    0  09-10-2004 21:26       Masachapa, Nicaragua
# ..         ...  ...               ...                        ...
# 28         6.7    9  06-02-2023 01:28            Nurdağı, Turkey
# 488        7.1    9  23-10-2011 10:41                Van, Turkey
# 61         6.7    9  13-03-2022 21:09        Pariaman, Indonesia
# 407        7.1    9  15-10-2013 00:12      Sagbayan, Philippines
# 27         7.5    9  06-02-2023 10:24            Ekinözü, Turkey
#
#      location_prices  testing  testing1
# 752             1000      6.8       inf
# 708             1000      7.1       inf
# 712             1000      6.7       inf
# ...

# %%
final_df.sort_values(['magnitude',"cdi"], ascending=True)
# Out:
#      magnitude  cdi         date_time  \
# 67         6.5    0  11-01-2022 12:39
# 68         6.5    0  11-01-2022 12:39
# 98         6.5    0  20-06-2021 17:05
# 108        6.5    0  04-03-2021 23:12
# 146        6.5    0  08-11-2019 10:44
# ..         ...  ...               ...
# 692        8.6    0  28-03-2005 16:09
# 476        8.6    9  11-04-2012 08:38
# 552        8.8    8  27-02-2010 06:34
# 703        9.1    0  26-12-2004 00:58
# 511        9.1    9  11-03-2011 05:46
#
#                                       location  location_prices  testing  \
# 67                            Nikolski, Alaska             1000      6.5
# 68                            Nikolski, Alaska             1000      6.5
# 98               Kermadec Islands, New Zealand             1000      6.5
# 108                    Kermadec Islands region             1000      6.5
# 146                          Ndoi Island, Fiji             1000      6.5
# ...

# %%
final_df.sort_values(['location'], key= lambda text:text.str.lower())
# Out:
#      magnitude  cdi         date_time  \
# 703        9.1    0  26-12-2004 00:58
# 511        9.1    9  11-03-2011 05:46
# 225        7.3    8  12-11-2017 18:18
# 510        7.9    8  11-03-2011 06:15
# 455        7.3    6  07-12-2012 08:18
# ..         ...  ...               ...
# 37         7.0    3  12-11-2022 07:09
# 39         6.6    0  09-11-2022 10:14
# 54         6.9    2  19-05-2022 10:13
# 103        6.9    7  01-05-2021 01:27
# 281        6.9    3  28-05-2016 05:38
#
#                                       location  location_prices  testing  \
# 703  2004 Sumatra - Andaman Islands Earthquake             1000      9.1
# 511        2011 Great Tohoku Earthquake, Japan             1000     18.1
# 225                              ?alabja, Iraq             1000     15.3
# 510                               ?arai, Japan             1000     15.9
# 455                             ?funato, Japan             1000     13.3
# ...

# %%
def summation(a , b):
  result = a + b
  print(result)

summation(1 , 3)
# Out:
# 4

# %%
1 + 3
# Out:
# 4

# %%
summation(39 , 29)
# Out:
# 68

# %%
summation(0 , 1)
# Out:
# 1

# %%
import requests
