# %%
import pandas as pd 
df = pd.read_csv('all_month.csv')

# %%
df
# Out:
#                           time   latitude   longitude       depth       mag  \
# 0     2025-04-04T02:10:57.540Z  38.792000 -122.761002    2.090000  1.070000
# 1     2025-04-04T02:00:43.020Z  45.330166 -121.694664    4.740000  1.772495
# 2     2025-04-04T01:39:39.290Z  19.255333 -155.399170   33.029999  2.210000
# 3     2025-04-04T01:37:07.106Z -16.330600  -72.483800  111.910000  4.800000
# 4     2025-04-04T01:28:38.129Z  31.521000 -104.001000    4.550400  2.400000
# ...                        ...        ...         ...         ...       ...
# 9629  2025-03-05T02:32:47.700Z  35.246333  -97.780333    4.640000  0.410000
# 9630  2025-03-05T02:32:37.450Z  40.775333 -121.490833   17.180000       NaN
# 9631  2025-03-05T02:32:28.830Z  40.744833 -121.494333   11.860000  1.630000
# 9632  2025-03-05T02:30:00.360Z  37.556167 -113.053667    9.750000  0.990000
# 9633  2025-03-05T02:29:56.939Z  62.938600 -156.197400    0.900000  2.300000
#
# ...

# %%
df.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
df = df[['depth','magType','type','horizontalError']]
df
# Out:
#            depth magType        type  horizontalError
# 0       2.090000      md  earthquake             0.28
# 1       4.740000      ml  earthquake             0.45
# 2      33.029999      ml  earthquake             0.35
# 3     111.910000      mb  earthquake            10.20
# 4       4.550400      ml  earthquake             0.00
# ...          ...     ...         ...              ...
# 9629    4.640000      ml  earthquake              NaN
# 9630   17.180000     NaN  earthquake             1.19
# 9631   11.860000      md  earthquake             0.26
# 9632    9.750000      ml  earthquake             0.29
# 9633    0.900000      ml  earthquake              NaN
#
# [9634 rows x 4 columns]

# %%
df['verticalError'] = df['horizontalError']/2
df
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9744\3093904870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['verticalError'] = df['horizontalError']/2
#            depth magType        type  horizontalError  verticalError
# 0       2.090000      md  earthquake             0.28          0.140
# 1       4.740000      ml  earthquake             0.45          0.225
# 2      33.029999      ml  earthquake             0.35          0.175
# 3     111.910000      mb  earthquake            10.20          5.100
# 4       4.550400      ml  earthquake             0.00          0.000
# ...          ...     ...         ...              ...            ...
# 9629    4.640000      ml  earthquake              NaN            NaN
# ...

# %%
df['type'].value_counts()
# Out:
# type
# earthquake      9443
# quarry blast     117
# explosion         70
# ice quake          4
# Name: count, dtype: int64

# %%
df['type'].value_counts(normalize=True)
# Out:
# type
# earthquake      0.980174
# quarry blast    0.012144
# explosion       0.007266
# ice quake       0.000415
# Name: proportion, dtype: float64

# %%
df.isna().sum()
# Out:
# depth                 0
# magType               1
# type                  0
# horizontalError    2270
# verticalError      2270
# dtype: int64

# %%
df1 = df.copy()
df1
# Out:
#            depth magType        type  horizontalError  verticalError
# 0       2.090000      md  earthquake             0.28          0.140
# 1       4.740000      ml  earthquake             0.45          0.225
# 2      33.029999      ml  earthquake             0.35          0.175
# 3     111.910000      mb  earthquake            10.20          5.100
# 4       4.550400      ml  earthquake             0.00          0.000
# ...          ...     ...         ...              ...            ...
# 9629    4.640000      ml  earthquake              NaN            NaN
# 9630   17.180000     NaN  earthquake             1.19          0.595
# 9631   11.860000      md  earthquake             0.26          0.130
# 9632    9.750000      ml  earthquake             0.29          0.145
# 9633    0.900000      ml  earthquake              NaN            NaN
#
# [9634 rows x 5 columns]

# %%
import numpy as np 

df1['horizontalError'] = df['horizontalError'].replace(np.NaN, df['horizontalError'].mean())
df1
# Out:
#            depth magType        type  horizontalError  verticalError
# 0       2.090000      md  earthquake         0.280000          0.140
# 1       4.740000      ml  earthquake         0.450000          0.225
# 2      33.029999      ml  earthquake         0.350000          0.175
# 3     111.910000      mb  earthquake        10.200000          5.100
# 4       4.550400      ml  earthquake         0.000000          0.000
# ...          ...     ...         ...              ...            ...
# 9629    4.640000      ml  earthquake         1.664508            NaN
# 9630   17.180000     NaN  earthquake         1.190000          0.595
# 9631   11.860000      md  earthquake         0.260000          0.130
# 9632    9.750000      ml  earthquake         0.290000          0.145
# 9633    0.900000      ml  earthquake         1.664508            NaN
#
# [9634 rows x 5 columns]

# %%
df1['horizontalError']
# Out:
# 0        0.280000
# 1        0.450000
# 2        0.350000
# 3       10.200000
# 4        0.000000
#           ...
# 9629     1.664508
# 9630     1.190000
# 9631     0.260000
# 9632     0.290000
# 9633     1.664508
# Name: horizontalError, Length: 9634, dtype: float64

# %%
df1.isna().sum()
# Out:
# depth                 0
# magType               1
# type                  0
# horizontalError       0
# verticalError      2270
# dtype: int64

# %%
df1['horizontalError'] = df1['horizontalError'].replace(np.NaN, df1['horizontalError'].median())

# %%
df1
# Out:
#            depth magType        type  horizontalError  verticalError
# 0       2.090000      md  earthquake             0.28          0.140
# 1       4.740000      ml  earthquake             0.45          0.225
# 2      33.029999      ml  earthquake             0.35          0.175
# 3     111.910000      mb  earthquake            10.20          5.100
# 4       4.550400      ml  earthquake             0.00          0.000
# ...          ...     ...         ...              ...            ...
# 9629    4.640000      ml  earthquake             0.44            NaN
# 9630   17.180000     NaN  earthquake             1.19          0.595
# 9631   11.860000      md  earthquake             0.26          0.130
# 9632    9.750000      ml  earthquake             0.29          0.145
# 9633    0.900000      ml  earthquake             0.44            NaN
#
# [9634 rows x 5 columns]

# %%
df1.isna().sum()
# Out:
# depth                 0
# magType               1
# type                  0
# horizontalError       0
# verticalError      2270
# dtype: int64

# %%
df1['horizontalError']
# Out:
# 0        0.28
# 1        0.45
# 2        0.35
# 3       10.20
# 4        0.00
#         ...
# 9629      NaN
# 9630     1.19
# 9631     0.26
# 9632     0.29
# 9633      NaN
# Name: horizontalError, Length: 9634, dtype: float64

# %%
import statistics
df2 = df.copy()
df2['horizontalError'] = df2['horizontalError'].replace(np.NaN, statistics.mode(df2['horizontalError']))

# %%
df2
# Out:
#            depth magType        type  horizontalError  verticalError
# 0       2.090000      md  earthquake             0.28          0.140
# 1       4.740000      ml  earthquake             0.45          0.225
# 2      33.029999      ml  earthquake             0.35          0.175
# 3     111.910000      mb  earthquake            10.20          5.100
# 4       4.550400      ml  earthquake             0.00          0.000
# ...          ...     ...         ...              ...            ...
# 9629    4.640000      ml  earthquake             0.25            NaN
# 9630   17.180000     NaN  earthquake             1.19          0.595
# 9631   11.860000      md  earthquake             0.26          0.130
# 9632    9.750000      ml  earthquake             0.29          0.145
# 9633    0.900000      ml  earthquake             0.25            NaN
#
# [9634 rows x 5 columns]

# %%
df2.isna().sum()
# Out:
# depth                 0
# magType               1
# type                  0
# horizontalError       0
# verticalError      2270
# dtype: int64

# %%
df1['horizontalError'] = df1['horizontalError'].interpolate(method='linear',axis=0)

# %%
df1
# Out:
#            depth magType        type  horizontalError  verticalError
# 0       2.090000      md  earthquake         0.280000          0.140
# 1       4.740000      ml  earthquake         0.450000          0.225
# 2      33.029999      ml  earthquake         0.350000          0.175
# 3     111.910000      mb  earthquake        10.200000          5.100
# 4       4.550400      ml  earthquake         0.000000          0.000
# ...          ...     ...         ...              ...            ...
# 9629    4.640000      ml  earthquake         1.033828            NaN
# 9630   17.180000     NaN  earthquake         1.190000          0.595
# 9631   11.860000      md  earthquake         0.260000          0.130
# 9632    9.750000      ml  earthquake         0.290000          0.145
# 9633    0.900000      ml  earthquake         0.290000            NaN
#
# [9634 rows x 5 columns]
