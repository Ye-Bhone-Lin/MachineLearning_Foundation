# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_train.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df1 = pd.read_csv("/content/sample_data/california_housing_test.csv")
df1
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
final_df = pd.concat([df,df1])
final_df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -114.31     34.19                15.0       5612.0          1283.0
# 1       -114.47     34.40                19.0       7650.0          1901.0
# 2       -114.56     33.69                17.0        720.0           174.0
# 3       -114.57     33.64                14.0       1501.0           337.0
# 4       -114.57     33.57                20.0       1454.0           326.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
final_df = final_df.reset_index()
final_df
# Out:
#        level_0  index  longitude  latitude  housing_median_age  total_rooms  \
# 0            0      0    -114.31     34.19                15.0       5612.0
# 1            1      1    -114.47     34.40                19.0       7650.0
# 2            2      2    -114.56     33.69                17.0        720.0
# 3            3      3    -114.57     33.64                14.0       1501.0
# 4            4      4    -114.57     33.57                20.0       1454.0
# ...        ...    ...        ...       ...                 ...          ...
# 19995    19995   2995    -119.86     34.42                23.0       1450.0
# 19996    19996   2996    -118.14     34.06                27.0       5257.0
# 19997    19997   2997    -119.70     36.30                10.0        956.0
# 19998    19998   2998    -117.12     34.10                40.0         96.0
# 19999    19999   2999    -119.63     34.42                42.0       1765.0
#
# ...

# %%
final_df = final_df.drop(columns=['level_0', "index"])
final_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 19995    -119.86     34.42                23.0       1450.0           642.0
# 19996    -118.14     34.06                27.0       5257.0          1082.0
# 19997    -119.70     36.30                10.0        956.0           201.0
# 19998    -117.12     34.10                40.0         96.0            14.0
# 19999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
x = final_df.iloc[:,:-1]
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 19995    -119.86     34.42                23.0       1450.0           642.0
# 19996    -118.14     34.06                27.0       5257.0          1082.0
# 19997    -119.70     36.30                10.0        956.0           201.0
# 19998    -117.12     34.10                40.0         96.0            14.0
# 19999    -119.63     34.42                42.0       1765.0           263.0
#
#        population  households  median_income
# ...

# %%
y = final_df.iloc[:,-1]
y
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 19995    225000.0
# 19996    237200.0
# 19997     62000.0
# 19998    162500.0
# 19999    500001.0
# Name: median_house_value, Length: 20000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=0)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (14000, 8)
# (14000,)
# (6000, 8)
# (6000,)

# %%
from sklearn.svm import SVR

model = SVR()
model.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mean_squared_error(y_test,y_pred)
# Out:
# 14095346649.75628

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 88542.62256632064

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [0.1, 1],
			'gamma': [1, 0.1],
			'kernel': ['rbf']}

# %%
grid_search = GridSearchCV(model, param_grid=param_grid,refit = True, verbose = 3 )

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.052 total time=   7.5s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.061 total time=   7.9s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.049 total time=   6.8s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.049 total time=   8.1s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.062 total time=   8.1s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.052 total time=   6.8s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.061 total time=   8.2s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.049 total time=   6.9s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.049 total time=  12.5s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=rbf;, score=-0.062 total time=  12.2s
# [CV 1/5] END .........C=1, gamma=1, kernel=rbf;, score=-0.052 total time=  11.4s
# ...

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# -0.0545132043936523

# %%
latest_y_predict = grid_search.predict(x_test)
mean_squared_error(y_test,latest_y_predict)
# Out:
# 14111025139.212635
